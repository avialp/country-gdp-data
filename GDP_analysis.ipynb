# %% [markdown]
# # Country GDP Analysis

# %% [markdown]
# In this analysis, we'll be taking a look at 5 out of 266 countries to determine a general trend in GDP.

# %% [markdown]
# ## Dataset: Countries GDP 2012 to 2021 ([link](https://www.kaggle.com/datasets/yapwh1208/countries-gdp-2012-to-2021))

# %%
# upload csv
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1ae9f48-8cc2-4223-8587-34c1c3ede09b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1ae9f48-8cc2-4223-8587-34c1c3ede09b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import pandas and NumPy
import pandas as pd
import numpy as np

# %%
# create data frame and table
df = pd.read_csv('gdp.csv')
df.head()
# Out:
#      Country Name Country Code         2012         2013         2014  \
# 0     Afghanistan          AFG  18171512502  19189252517  19712072023
# 1         Albania          ALB  10836881664  10945469119  11139690870
# 2         Algeria          DZA     1.50E+11     1.54E+11     1.60E+11
# 3  American Samoa          ASM  657587786.3  641148091.6  652450381.7
# 4         Andorra          AND   2781915942   2683224789   2750425228
#
#           2015         2016         2017         2018         2019  \
# 0  19998156214  20450177379  20991494229  21241130983  22071999789
# 1  11386850130  11764322012  12211628287  12702457551  12967692915
# 2     1.66E+11     1.71E+11     1.74E+11     1.76E+11     1.77E+11
# 3    673000000  661697709.9  615461068.7  631900763.4  628818320.6
# 4   2789870188   2893365390   2903378514   2949506390   3008955097
#
#           2020         2021
# 0  21553064853  17083574409
# 1  12516205780  13582023424
# 2     1.68E+11     1.74E+11
# ...

# %%
# drop Country Code column
to_drop = ['Country Code']
df.drop(to_drop, inplace=True, axis=1)

# %%
# new table without Country Code column
df.head()
# Out:
#      Country Name         2012         2013         2014         2015  \
# 0     Afghanistan  18171512502  19189252517  19712072023  19998156214
# 1         Albania  10836881664  10945469119  11139690870  11386850130
# 2         Algeria     1.50E+11     1.54E+11     1.60E+11     1.66E+11
# 3  American Samoa  657587786.3  641148091.6  652450381.7    673000000
# 4         Andorra   2781915942   2683224789   2750425228   2789870188
#
#           2016         2017         2018         2019         2020  \
# 0  20450177379  20991494229  21241130983  22071999789  21553064853
# 1  11764322012  12211628287  12702457551  12967692915  12516205780
# 2     1.71E+11     1.74E+11     1.76E+11     1.77E+11     1.68E+11
# 3  661697709.9  615461068.7  631900763.4  628818320.6    660670229
# 4   2893365390   2903378514   2949506390   3008955097   2672435366
#
#           2021
# 0  17083574409
# 1  13582023424
# 2     1.74E+11
# 3    648340458
# 4   2911602777

# %%
# graph for GDP growth in 2012
data = {'Country Name': ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra'],
        '2012': [18171512502, 10836881664, 1.50E+11, 657587786.3, 2781915942]
       }
df = pd.DataFrame(data)

colors = ['green','blue','purple','brown','teal']
plt.bar(df['Country Name'], df['2012'], color=colors)
plt.title('Country Vs GDP in 2012', fontsize=14)
plt.xlabel('Country', fontsize=14)
plt.ylabel('2012', fontsize=14)
plt.grid(True)
plt.show()

# %%
# graph for GDP growth in 2021
data = {'Country Name': ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra'],
        '2021': [17083574409, 13582023424, 1.74E+11, 648340458, 2911602777]
       }
df = pd.DataFrame(data)

colors = ['green','blue','purple','brown','teal']
plt.bar(df['Country Name'], df['2021'], color=colors)
plt.title('Country Vs GDP in 2021', fontsize=14)
plt.xlabel('Country', fontsize=14)
plt.ylabel('2012', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# While other countries on the list experienced a growth in GDP, Afghanistan and American Samoa suffered from decreasing GDPs. Afghanistan's decrease in GDP could be due to ongoing conflict and diminishing resources, whereas American Samoa can be attributed to a decrease in exportation of goods.

# %%
# line graph to visualize Afghanistan's GDP
df = pd.DataFrame({
   'Afghanistan': [18171512502, 19189252517, 19712072023, 19998156214, 20450177379, 20991494229, 21241130983	, 2071999789, 21553064853, 17083574409],
   }, index=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
lines = df.plot.line()
